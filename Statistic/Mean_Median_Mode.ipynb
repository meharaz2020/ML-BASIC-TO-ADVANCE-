# %%
# Module Import
import numpy as np
from scipy import stats
#import scipy.stats as st

# %%
input_number_size = int(input("Enter the Size of the Input Number"))
number_list_generate = list(map(int, input().split()))
# Out:
# Enter the Size of the Input Number 10
#  1 2 2 3 4 5 5 5 8 9

# %%
number_list_generate
# Out:
# [1, 2, 2, 3, 4, 5, 5, 5, 8, 9]

# %%
print("Mean Value is :", np.mean(number_list_generate))
print("Median Value is :", np.median(number_list_generate))
print("Mode Value is :", int(stats.mode(number_list_generate)[0]))
# Out:
# Mean Value is : 4.4
# Median Value is : 4.5
# Mode Value is : 5

# %%
a = np.random.randn(1, 10, 10)
a
# Out:
# array([[[ 1.85801948, -0.14356764,  0.56818034, -0.50820762,
#          -1.54807061, -0.02728358, -0.83067567, -2.06705968,
#           1.07435252,  1.62694129],
#         [ 0.52274381,  0.43472754, -0.15881679,  0.25282976,
#           0.81492249,  1.14542879, -1.97925877, -0.26141513,
#           1.6004969 ,  0.56628156],
#         [ 1.05848412,  0.10269706, -0.66570777,  1.64341485,
#           0.2774538 , -1.06076366, -0.44728853,  0.0630383 ,
#           2.02479284,  0.59882742],
#         [ 1.23484817, -0.30026006,  0.93038002,  0.20428273,
#          -0.40515718,  0.61501249, -1.44338238, -0.06723861,
#           0.58916644,  0.0975324 ],
#         [-0.8617887 , -0.08332976,  0.20111824,  0.86633722,
#           1.01986175, -1.08744211, -0.33792231,  2.20565303,
#           0.56440828, -1.28232083],
#         [-1.2401519 , -1.11677877,  0.69918932,  0.09048079,
#           1.79590251, -0.11115287, -0.25557333,  0.34373136,
#           0.54404737, -1.8253492 ],
#         [-0.88268154,  0.12034997,  0.3613701 , -0.00803302,
#           0.86026569, -0.56109371,  0.21165008, -1.28878388,
#           0.69500713,  0.14705142],
#         [ 0.48706434,  1.49028189,  0.67355319, -0.51740371,
#           1.19525119,  0.13504509, -0.78324274, -0.12442804,
#           0.30575187, -1.35405195],
#         [-0.7797405 , -0.29640221, -0.3949049 , -0.61304735,
#          -1.03480316, -1.06352848, -0.92027552, -0.22721535,
#          -0.63095513, -0.99318041],
#         [-1.58011099, -1.70159132,  0.98312934,  0.24164048,
#           1.25106099,  0.25972599, -0.63196223,  0.49439571,
#           0.49581221, -0.12292835]]])

# %%
np.max(a)
# Out:
# 0.999894264007004

# %%
np.median(a)
# Out:
# 53.0

# %%
np.std(a)
# Out:
# 28.8562142354121
